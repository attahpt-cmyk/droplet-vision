# %%
with open('../data/notes.txt', 'w') as f: 
    f.write("Session 1: baseline measurements\n") 
    f.write("Session 2: increased flow rate\n")

# %%
with open('../data/notes.txt', 'r') as f: 
    contents = f.read() 
print(contents)
# Out:
# Session 1: baseline measurements
# Session 2: increased flow rate

# %%
with open('../data/notes.txt', 'r') as f: 
  for line in f: 
    print(line.strip())
# Out:
# Session 1: baseline measurements
# Session 2: increased flow rate

# %%
from pathlib import Path 
data_folder = Path('../data') 
files = list(data_folder.glob('*.csv')) 
print(files) 
for f in files: 
    print(f.name, f.stem, f.suffix)
# Out:
# [WindowsPath('../data/synthetic_droplets.csv')]
# ('synthetic_droplets.csv', 'synthetic_droplets', '.csv')
